# %%
s1='abc'
s2="abc"
s3="""
    a
    b
    c
    """
print(s1,s2,s3)
# Out:
# abc abc
#     a
#     b
#     c

# %%
name = "unknown"
age = 20

print("His name is %s" % name)
print("Hello,{}".format(name))
print(f"His name is {name} and is {age} years old")
# Out:
# His name is unknown
# Hello,unknown
# His name is unknown and is 20 years old

# %%
s2="abcdefghijk"
f=s2[0]
l=len(s2)
l2=s2[l-2:l]
print(f+l2)
# Out:
# ajk

# %%
s3="abdjksab"
l=s3.lower()
a1=l[0:2]
l=len(s3)
l2=s2[l-2:l]
lu=l2.upper()
print(a1+lu)
# Out:
# abGH
