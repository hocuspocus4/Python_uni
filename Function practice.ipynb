# %%
def greet(name):
    name=name.upper()
    print(f"Hello {name}")

# %%
greet("jewndk")
# Out:
# Hello JEWNDK

# %%
def calc_area(h,w):
    ar=h*w
    print(ar)

calc_area(823,33)
# Out:
# 27159

# %%
def intro(name,age):
    print(f"The name is {name} and is {age} years old")

intro("Romano",20)
# Out:
# The name is Romano and is 20 years old

# %%
def first_last(n):
    n1=n[0]
    nl=n[-1]
    print(f"First is {n1} and last is {nl}")
n=[1,2,3,4,5,6]
first_last(n)
# Out:
# First is 1 and last is 6

# %%
import numpy as np

# %%
from numpy import arange
arange(start=100,stop=300,step=20)
# Out:
# array([100, 120, 140, 160, 180, 200, 220, 240, 260, 280])
