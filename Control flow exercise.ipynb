# %%
# 1. 

n=float(input("Enter a number : "))
if n>0:
    print("Positive")
elif n==0:
    print("Zero")
else:
    print("Negative")
# Out:
# Enter a number :  90
# Positive

# %%
# 2.
age=int(input("Enter Age : "))
if age < 13:
    print("Child")
else:
    if age <= 19:
        print("Teenager")
    else:
        if age <= 65:
            print("Adult")
        else:
            print("Senior")
# Out:
# Enter Age :  40
# Adult

# %%
# 3.

marks=int(input("Please enter marks :"))
if marks<60:
    print("F")
elif marks>=60 and marks<70:
    print("D")
elif marks>=70 and marks<80:
    print("c")
elif marks>=80 and marks<90:
    print("B")
else:
    print("A")
# Out:
# Please enter marks : 75
# c

# %%
# 4.

t=input()
t1=input()
b1=t=="True"
b2=t1=="True"

print(f"AND {t and t1}")
print(f"OR {t or t1}")
print(f"NOT first input {not t}")
print(f"NOT 2nd input {not t1}")
# Out:
#  TRUE
#  FALSE
# AND FALSE
# OR TRUE
# NOT first input False
# NOT 2nd input False
