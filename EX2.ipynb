# %%
10%3
10//5
# Out:
# 2

# %%
def is_even(a):
    """
    this func returns true if the number is even otherwise false
    """
    return a%2==0 #returns true if 0 otherwise false
is_even(21)
# Out:
# False

# %%
a=10
b=5
a+=b
a
# Out:
# 15

# %%
s1="Today is a nice sunny day"
len(s1)
s1[-10:]
s1[0:25:3]

s1.upper()
s1.find("sunny")
s1.replace("sunny","overcast".upper())
# Out:
# 'Today is a nice OVERCAST day'

# %%
name="unknown"
age=22
print(f'his name is {name} and is {age} years old')
# Out:
# his name is unknown and is 22 years old
