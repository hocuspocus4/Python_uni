# %%
if 10>5:
    print("ten is greater than 5")
# Out:
# ten is greater than 5

# %%
def sum(a,b):
    """
    ADDING TWO INT FUNC
    """
    rs=a+b
    return rs
sum(10,5)
# Out:
# 15

# %%
if 10>500:
    print("ten is greater than 5")
else:
    print("its lower than 5")

print("END")
# Out:
# its lower than 5
# END

# %%
age=20
age
# Out:
# 20

# %%
Age=30
Age
# Out:
# 30

# %%
building1_name="ABC"
building1_height=100

building2_name="ABCD"
building2_height=1000

building3_name="ABCD"
building3_height=1000

print("",building1_name,building1_height,"\n",building2_name,building2_height,"\n",building3_name,building3_height)
# Out:
#  ABC 100
#  ABCD 1000
#  ABCD 1000

# %%
age=49.5
type(age)
# Out:
# float

# %%
stu_name="Sayantan"
stu_name
# Out:
# 'Sayantan'

# %%
a=10
b="lallalal"
c=True
d=9.8



dangerous=True
print(a,b,c,d)
# Out:
# 10 lallalal True 9.8

# %%
maxdistance=50
temp=30.1
greet_ing="hello"
isRaining=False

value_1=1
total_amt=40
calc_num=1
data_entry="abc"

# %%
n1=float(42)
n2=int(3.14159)
n3=str(99.99)
n3=float(n3)

# %%
type(n1)
type(n2)
type(n3)
# Out:
# float
