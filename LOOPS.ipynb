# %% [markdown]
# # FOR

# %%
my_list={1,4,7,-10,-9,0}
my_list
# Out:
# {-10, -9, 0, 1, 4, 7}

# %%
for i in my_list:
    print(i)
# Out:
# 0
# 1
# -9
# 4
# -10
# 7

# %%
my_tuple=(3,1,"hello",True)
for i in my_tuple:
    print(i)
# Out:
# 3
# 1
# hello
# True

# %% [markdown]
# # While

# %%
count=0
while count<10:
    print(count)
    count+=1
